# %%
import os

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme(style='white', palette='muted', font_scale=1.15)

# %%
def calculate_error_rate(fp, fn, tp, tn):
    """
        error rate = (fp + fn) / (fp + fn + tp + tn)
    """
    return (fp+fn) / (fp+fn+tp+tn)

def calculate_accuracy(fp, fn, tp, tn):
    """
        accuracy = (tp + tn) / (fp + fn + tp + tn)
    """
    return (tp+tn) / (fp+fn+tp+tn)

def calculate_recall(fn, tp):
    """
        recall (sensitivity or TPR) = tp / (fn + tp)
    """
    return tp / (fn+tp)

def calculate_specificity(fp, tn):
    """
        specificity (TNR) = tn / (fp + tn)
    """
    return tn / (fp+tn)

def calculate_precision(tp, fp):
    """
        precision = tp / (tp + fp)
    """
    return tp / (tp + fp)

# %% [markdown]
# ## LSTM AE

# %% [markdown]
# ### LSTM AE (sws=8, wavelet)

# %%
# la = 0
tn_sws8_la0, fp_sws8_la0, tp_sws8_la0, fn_sws8_la0 = 98169, 6417, 18244, 3181
err_sws8_la0 = calculate_error_rate(fp_sws8_la0, fn_sws8_la0, tp_sws8_la0, tn_sws8_la0)
acc_sws8_la0 = calculate_accuracy(fp_sws8_la0, fn_sws8_la0, tp_sws8_la0, tn_sws8_la0)
rec_sws8_la0 = calculate_recall(fn_sws8_la0, tp_sws8_la0)
spec_sws8_la0 = calculate_specificity(fp_sws8_la0, tn_sws8_la0)
prec_sws8_la0 = calculate_precision(tp_sws8_la0, fp_sws8_la0)

# la = 50
tn_sws8_la50, fp_sws8_la50, tp_sws8_la50, fn_sws8_la50 = 96017, 5769, 15522, 5903
err_sws8_la50 = calculate_error_rate(fp_sws8_la50, fn_sws8_la50, tp_sws8_la50, tn_sws8_la50)
acc_sws8_la50 = calculate_accuracy(fp_sws8_la50, fn_sws8_la50, tp_sws8_la50, tn_sws8_la50)
rec_sws8_la50 = calculate_recall(fn_sws8_la50, tp_sws8_la50)
spec_sws8_la50 = calculate_specificity(fp_sws8_la50, tn_sws8_la50)
prec_sws8_la50 = calculate_precision(tp_sws8_la50, fp_sws8_la50)

# la = 100
tn_sws8_la100, fp_sws8_la100, tp_sws8_la100, fn_sws8_la100 = 93403, 5583, 12837, 8588
err_sws8_la100 = calculate_error_rate(fp_sws8_la100, fn_sws8_la100, tp_sws8_la100, tn_sws8_la100)
acc_sws8_la100 = calculate_accuracy(fp_sws8_la100, fn_sws8_la100, tp_sws8_la100, tn_sws8_la100)
rec_sws8_la100 = calculate_recall(fn_sws8_la100, tp_sws8_la100)
spec_sws8_la100 = calculate_specificity(fp_sws8_la100, tn_sws8_la100)
prec_sws8_la100 = calculate_precision(tp_sws8_la100, fp_sws8_la100)

# la = 150
tn_sws8_la150, fp_sws8_la150, tp_sws8_la150, fn_sws8_la150 = 90813, 5373, 10212, 11213
err_sws8_la150 = calculate_error_rate(fp_sws8_la150, fn_sws8_la150, tp_sws8_la150, tn_sws8_la150)
acc_sws8_la150 = calculate_accuracy(fp_sws8_la150, fn_sws8_la150, tp_sws8_la150, tn_sws8_la150)
rec_sws8_la150 = calculate_recall(fn_sws8_la150, tp_sws8_la150)
spec_sws8_la150 = calculate_specificity(fp_sws8_la150, tn_sws8_la150)
prec_sws8_la150 = calculate_precision(tp_sws8_la150, fp_sws8_la150)

# la = 200
tn_sws8_la200, fp_sws8_la200, tp_sws8_la200, fn_sws8_la200 = 88106, 5280, 8078, 13347
err_sws8_la200 = calculate_error_rate(fp_sws8_la200, fn_sws8_la200, tp_sws8_la200, tn_sws8_la200)
acc_sws8_la200 = calculate_accuracy(fp_sws8_la200, fn_sws8_la200, tp_sws8_la200, tn_sws8_la200)
rec_sws8_la200 = calculate_recall(fn_sws8_la200, tp_sws8_la200)
spec_sws8_la200 = calculate_specificity(fp_sws8_la200, tn_sws8_la200)
prec_sws8_la200 = calculate_precision(tp_sws8_la200, fp_sws8_la200)

# %% [markdown]
# ### LSTM AE (sws=16, wavelet)

# %%
# la = 0
tn_sws16_la0, fp_sws16_la0, tp_sws16_la0, fn_sws16_la0 = 97747, 6391, 18177, 3248
err_sws16_la0 = calculate_error_rate(fp_sws16_la0, fn_sws16_la0, tp_sws16_la0, tn_sws16_la0)
acc_sws16_la0 = calculate_accuracy(fp_sws16_la0, fn_sws16_la0, tp_sws16_la0, tn_sws16_la0)
rec_sws16_la0 = calculate_recall(fn_sws16_la0, tp_sws16_la0)
spec_sws16_la0 = calculate_specificity(fp_sws16_la0, tn_sws16_la0)
prec_sws16_la0 = calculate_precision(tp_sws16_la0, fp_sws16_la0)

# la = 50
tn_sws16_la50, fp_sws16_la50, tp_sws16_la50, fn_sws16_la50 = 95463, 5875, 15421, 6004
err_sws16_la50 = calculate_error_rate(fp_sws16_la50, fn_sws16_la50, tp_sws16_la50, tn_sws16_la50)
acc_sws16_la50 = calculate_accuracy(fp_sws16_la50, fn_sws16_la50, tp_sws16_la50, tn_sws16_la50)
rec_sws16_la50 = calculate_recall(fn_sws16_la50, tp_sws16_la50)
spec_sws16_la50 = calculate_specificity(fp_sws16_la50, tn_sws16_la50)
prec_sws16_la50 = calculate_precision(tp_sws16_la50, fp_sws16_la50)

# la = 100
tn_sws16_la100, fp_sws16_la100, tp_sws16_la100, fn_sws16_la100 = 92893, 5645, 12676, 8749
err_sws16_la100 = calculate_error_rate(fp_sws16_la100, fn_sws16_la100, tp_sws16_la100, tn_sws16_la100)
acc_sws16_la100 = calculate_accuracy(fp_sws16_la100, fn_sws16_la100, tp_sws16_la100, tn_sws16_la100)
rec_sws16_la100 = calculate_recall(fn_sws16_la100, tp_sws16_la100)
spec_sws16_la100 = calculate_specificity(fp_sws16_la100, tn_sws16_la100)
prec_sws16_la100 = calculate_precision(tp_sws16_la100, fp_sws16_la100)

# la = 150
tn_sws16_la150, fp_sws16_la150, tp_sws16_la150, fn_sws16_la150 = 90369, 5369, 10145, 11280
err_sws16_la150 = calculate_error_rate(fp_sws16_la150, fn_sws16_la150, tp_sws16_la150, tn_sws16_la150)
acc_sws16_la150 = calculate_accuracy(fp_sws16_la150, fn_sws16_la150, tp_sws16_la150, tn_sws16_la150)
rec_sws16_la150 = calculate_recall(fn_sws16_la150, tp_sws16_la150)
spec_sws16_la150 = calculate_specificity(fp_sws16_la150, tn_sws16_la150)
prec_sws16_la150 = calculate_precision(tp_sws16_la150, fp_sws16_la150)

# la = 200
tn_sws16_la200, fp_sws16_la200, tp_sws16_la200, fn_sws16_la200 = 87860, 5078, 8049, 13376
err_sws16_la200 = calculate_error_rate(fp_sws16_la200, fn_sws16_la200, tp_sws16_la200, tn_sws16_la200)
acc_sws16_la200 = calculate_accuracy(fp_sws16_la200, fn_sws16_la200, tp_sws16_la200, tn_sws16_la200)
rec_sws16_la200 = calculate_recall(fn_sws16_la200, tp_sws16_la200)
spec_sws16_la200 = calculate_specificity(fp_sws16_la200, tn_sws16_la200)
prec_sws16_la200 = calculate_precision(tp_sws16_la200, fp_sws16_la200)

# %% [markdown]
# ### LSTM AE (sws=16, rnn)

# %%
# la = 0
tn_sws16_la0_rnn, fp_sws16_la0_rnn, tp_sws16_la0_rnn, fn_sws16_la0_rnn = 92950, 11188, 19311, 2114
err_sws16_la0_rnn = calculate_error_rate(fp_sws16_la0_rnn, fn_sws16_la0_rnn, tp_sws16_la0_rnn, tn_sws16_la0_rnn)
acc_sws16_la0_rnn = calculate_accuracy(fp_sws16_la0_rnn, fn_sws16_la0_rnn, tp_sws16_la0_rnn, tn_sws16_la0_rnn)
rec_sws16_la0_rnn = calculate_recall(fn_sws16_la0_rnn, tp_sws16_la0_rnn)
spec_sws16_la0_rnn = calculate_specificity(fp_sws16_la0_rnn, tn_sws16_la0_rnn)
prec_sws16_la0_rnn = calculate_precision(tp_sws16_la0_rnn, fp_sws16_la0_rnn)

# la = 50
tn_sws16_la50_rnn, fp_sws16_la50_rnn, tp_sws16_la50_rnn, fn_sws16_la50_rnn = 91550, 9788, 17070, 4355
err_sws16_la50_rnn = calculate_error_rate(fp_sws16_la50_rnn, fn_sws16_la50_rnn, tp_sws16_la50_rnn, tn_sws16_la50_rnn)
acc_sws16_la50_rnn = calculate_accuracy(fp_sws16_la50_rnn, fn_sws16_la50_rnn, tp_sws16_la50_rnn, tn_sws16_la50_rnn)
rec_sws16_la50_rnn = calculate_recall(fn_sws16_la50_rnn, tp_sws16_la50_rnn)
spec_sws16_la50_rnn = calculate_specificity(fp_sws16_la50_rnn, tn_sws16_la50_rnn)
prec_sws16_la50_rnn = calculate_precision(tp_sws16_la50_rnn, fp_sws16_la50_rnn)

# la = 100
tn_sws16_la100_rnn, fp_sws16_la100_rnn, tp_sws16_la100_rnn, fn_sws16_la100_rnn = 91037, 7501, 14212, 7213
err_sws16_la100_rnn = calculate_error_rate(fp_sws16_la100_rnn, fn_sws16_la100_rnn, tp_sws16_la100_rnn, tn_sws16_la100_rnn)
acc_sws16_la100_rnn = calculate_accuracy(fp_sws16_la100_rnn, fn_sws16_la100_rnn, tp_sws16_la100_rnn, tn_sws16_la100_rnn)
rec_sws16_la100_rnn = calculate_recall(fn_sws16_la100_rnn, tp_sws16_la100_rnn)
spec_sws16_la100_rnn = calculate_specificity(fp_sws16_la100_rnn, tn_sws16_la100_rnn)
prec_sws16_la100_rnn = calculate_precision(tp_sws16_la100_rnn, fp_sws16_la100_rnn)

# la = 150
tn_sws16_la150_rnn, fp_sws16_la150_rnn, tp_sws16_la150_rnn, fn_sws16_la150_rnn = 89615, 6123, 11121, 10304
err_sws16_la150_rnn = calculate_error_rate(fp_sws16_la150_rnn, fn_sws16_la150_rnn, tp_sws16_la150_rnn, tn_sws16_la150_rnn)
acc_sws16_la150_rnn = calculate_accuracy(fp_sws16_la150_rnn, fn_sws16_la150_rnn, tp_sws16_la150_rnn, tn_sws16_la150_rnn)
rec_sws16_la150_rnn = calculate_recall(fn_sws16_la150_rnn, tp_sws16_la150_rnn)
spec_sws16_la150_rnn = calculate_specificity(fp_sws16_la150_rnn, tn_sws16_la150_rnn)
prec_sws16_la150_rnn = calculate_precision(tp_sws16_la150_rnn, fp_sws16_la150_rnn)

# la = 200
tn_sws16_la200_rnn, fp_sws16_la200_rnn, tp_sws16_la200_rnn, fn_sws16_la200_rnn = 87303, 5635, 8943, 12482
err_sws16_la200_rnn = calculate_error_rate(fp_sws16_la200_rnn, fn_sws16_la200_rnn, tp_sws16_la200_rnn, tn_sws16_la200_rnn)
acc_sws16_la200_rnn = calculate_accuracy(fp_sws16_la200_rnn, fn_sws16_la200_rnn, tp_sws16_la200_rnn, tn_sws16_la200_rnn)
rec_sws16_la200_rnn = calculate_recall(fn_sws16_la200_rnn, tp_sws16_la200_rnn)
spec_sws16_la200_rnn = calculate_specificity(fp_sws16_la200_rnn, tn_sws16_la200_rnn)
prec_sws16_la200_rnn = calculate_precision(tp_sws16_la200_rnn, fp_sws16_la200_rnn)

# %% [markdown]
# ### LSTM AE (sws=32, wavelet)

# %%
# la = 0
tn_sws32_la0, fp_sws32_la0, tp_sws32_la0, fn_sws32_la0 = 97104, 6138, 18156, 3269
err_sws32_la0 = calculate_error_rate(fp_sws32_la0, fn_sws32_la0, tp_sws32_la0, tn_sws32_la0)
acc_sws32_la0 = calculate_accuracy(fp_sws32_la0, fn_sws32_la0, tp_sws32_la0, tn_sws32_la0)
rec_sws32_la0 = calculate_recall(fn_sws32_la0, tp_sws32_la0)
spec_sws32_la0 = calculate_specificity(fp_sws32_la0, tn_sws32_la0)
prec_sws32_la0 = calculate_precision(tp_sws32_la0, fp_sws32_la0)

# la = 50
tn_sws32_la50, fp_sws32_la50, tp_sws32_la50, fn_sws32_la50 = 94527, 5915, 15333, 6092
err_sws32_la50 = calculate_error_rate(fp_sws32_la50, fn_sws32_la50, tp_sws32_la50, tn_sws32_la50)
acc_sws32_la50 = calculate_accuracy(fp_sws32_la50, fn_sws32_la50, tp_sws32_la50, tn_sws32_la50)
rec_sws32_la50 = calculate_recall(fn_sws32_la50, tp_sws32_la50)
spec_sws32_la50 = calculate_specificity(fp_sws32_la50, tn_sws32_la50)
prec_sws32_la50 = calculate_precision(tp_sws32_la50, fp_sws32_la50)

# la = 100
tn_sws32_la100, fp_sws32_la100, tp_sws32_la100, fn_sws32_la100 = 92010, 5632, 12696, 8729
err_sws32_la100 = calculate_error_rate(fp_sws32_la100, fn_sws32_la100, tp_sws32_la100, tn_sws32_la100)
acc_sws32_la100 = calculate_accuracy(fp_sws32_la100, fn_sws32_la100, tp_sws32_la100, tn_sws32_la100)
rec_sws32_la100 = calculate_recall(fn_sws32_la100, tp_sws32_la100)
spec_sws32_la100 = calculate_specificity(fp_sws32_la100, tn_sws32_la100)
prec_sws32_la100 = calculate_precision(tp_sws32_la100, fp_sws32_la100)

# la = 150
tn_sws32_la150, fp_sws32_la150, tp_sws32_la150, fn_sws32_la150 = 89343, 5499, 10118, 11307
err_sws32_la150 = calculate_error_rate(fp_sws32_la150, fn_sws32_la150, tp_sws32_la150, tn_sws32_la150)
acc_sws32_la150 = calculate_accuracy(fp_sws32_la150, fn_sws32_la150, tp_sws32_la150, tn_sws32_la150)
rec_sws32_la150 = calculate_recall(fn_sws32_la150, tp_sws32_la150)
spec_sws32_la150 = calculate_specificity(fp_sws32_la150, tn_sws32_la150)
prec_sws32_la150 = calculate_precision(tp_sws32_la150, fp_sws32_la150)

# la = 200
tn_sws32_la200, fp_sws32_la200, tp_sws32_la200, fn_sws32_la200 = 86643, 5399, 8107, 13318
err_sws32_la200 = calculate_error_rate(fp_sws32_la200, fn_sws32_la200, tp_sws32_la200, tn_sws32_la200)
acc_sws32_la200 = calculate_accuracy(fp_sws32_la200, fn_sws32_la200, tp_sws32_la200, tn_sws32_la200)
rec_sws32_la200 = calculate_recall(fn_sws32_la200, tp_sws32_la200)
spec_sws32_la200 = calculate_specificity(fp_sws32_la200, tn_sws32_la200)
prec_sws32_la200 = calculate_precision(tp_sws32_la200, fp_sws32_la200)

# %% [markdown]
# ### LSTM AE (sws=32, RNN)

# %%
# la = 0
tn_sws32_la0_rnn, fp_sws32_la0_rnn, tp_sws32_la0_rnn, fn_sws32_la0_rnn = 91605, 11637, 19278, 2147
err_sws32_la0_rnn = calculate_error_rate(fp_sws32_la0_rnn, fn_sws32_la0_rnn, tp_sws32_la0_rnn, tn_sws32_la0_rnn)
acc_sws32_la0_rnn = calculate_accuracy(fp_sws32_la0_rnn, fn_sws32_la0_rnn, tp_sws32_la0_rnn, tn_sws32_la0_rnn)
rec_sws32_la0_rnn = calculate_recall(fn_sws32_la0_rnn, tp_sws32_la0_rnn)
spec_sws32_la0_rnn = calculate_specificity(fp_sws32_la0_rnn, tn_sws32_la0_rnn)
prec_sws32_la0_rnn = calculate_precision(tp_sws32_la0_rnn, fp_sws32_la0_rnn)

# la = 50
tn_sws32_la50_rnn, fp_sws32_la50_rnn, tp_sws32_la50_rnn, fn_sws32_la50_rnn = 91104, 9338, 16947, 4478
err_sws32_la50_rnn = calculate_error_rate(fp_sws32_la50_rnn, fn_sws32_la50_rnn, tp_sws32_la50_rnn, tn_sws32_la50_rnn)
acc_sws32_la50_rnn = calculate_accuracy(fp_sws32_la50_rnn, fn_sws32_la50_rnn, tp_sws32_la50_rnn, tn_sws32_la50_rnn)
rec_sws32_la50_rnn = calculate_recall(fn_sws32_la50_rnn, tp_sws32_la50_rnn)
spec_sws32_la50_rnn = calculate_specificity(fp_sws32_la50_rnn, tn_sws32_la50_rnn)
prec_sws32_la50_rnn = calculate_precision(tp_sws32_la50_rnn, fp_sws32_la50_rnn)

# la = 100
tn_sws32_la100_rnn, fp_sws32_la100_rnn, tp_sws32_la100_rnn, fn_sws32_la100_rnn = 90590, 7052, 14067, 7358
err_sws32_la100_rnn = calculate_error_rate(fp_sws32_la100_rnn, fn_sws32_la100_rnn, tp_sws32_la100_rnn, tn_sws32_la100_rnn)
acc_sws32_la100_rnn = calculate_accuracy(fp_sws32_la100_rnn, fn_sws32_la100_rnn, tp_sws32_la100_rnn, tn_sws32_la100_rnn)
rec_sws32_la100_rnn = calculate_recall(fn_sws32_la100_rnn, tp_sws32_la100_rnn)
spec_sws32_la100_rnn = calculate_specificity(fp_sws32_la100_rnn, tn_sws32_la100_rnn)
prec_sws32_la100_rnn = calculate_precision(tp_sws32_la100_rnn, fp_sws32_la100_rnn)

# la = 150
tn_sws32_la150_rnn, fp_sws32_la150_rnn, tp_sws32_la150_rnn, fn_sws32_la150_rnn = 88560, 6282, 11025, 10400
err_sws32_la150_rnn = calculate_error_rate(fp_sws32_la150_rnn, fn_sws32_la150_rnn, tp_sws32_la150_rnn, tn_sws32_la150_rnn)
acc_sws32_la150_rnn = calculate_accuracy(fp_sws32_la150_rnn, fn_sws32_la150_rnn, tp_sws32_la150_rnn, tn_sws32_la150_rnn)
rec_sws32_la150_rnn = calculate_recall(fn_sws32_la150_rnn, tp_sws32_la150_rnn)
spec_sws32_la150_rnn = calculate_specificity(fp_sws32_la150_rnn, tn_sws32_la150_rnn)
prec_sws32_la150_rnn = calculate_precision(tp_sws32_la150_rnn, fp_sws32_la150_rnn)

# la = 200
tn_sws32_la200_rnn, fp_sws32_la200_rnn, tp_sws32_la200_rnn, fn_sws32_la200_rnn = 86607, 5435, 8799, 12626
err_sws32_la200_rnn = calculate_error_rate(fp_sws32_la200_rnn, fn_sws32_la200_rnn, tp_sws32_la200_rnn, tn_sws32_la200_rnn)
acc_sws32_la200_rnn = calculate_accuracy(fp_sws32_la200_rnn, fn_sws32_la200_rnn, tp_sws32_la200_rnn, tn_sws32_la200_rnn)
rec_sws32_la200_rnn = calculate_recall(fn_sws32_la200_rnn, tp_sws32_la200_rnn)
spec_sws32_la200_rnn = calculate_specificity(fp_sws32_la200_rnn, tn_sws32_la200_rnn)
prec_sws32_la200_rnn = calculate_precision(tp_sws32_la200_rnn, fp_sws32_la200_rnn)

# %% [markdown]
# ### LSTM AE (sws=64, wavelet)

# %%
# la = 0
tn_sws64_la0, fp_sws64_la0, tp_sws64_la0, fn_sws64_la0 = 95675, 5775, 18091, 3334
err_sws64_la0 = calculate_error_rate(fp_sws64_la0, fn_sws64_la0, tp_sws64_la0, tn_sws64_la0)
acc_sws64_la0 = calculate_accuracy(fp_sws64_la0, fn_sws64_la0, tp_sws64_la0, tn_sws64_la0)
rec_sws64_la0 = calculate_recall(fn_sws64_la0, tp_sws64_la0)
spec_sws64_la0 = calculate_specificity(fp_sws64_la0, tn_sws64_la0)
prec_sws64_la0 = calculate_precision(tp_sws64_la0, fp_sws64_la0)

# la = 50
tn_sws64_la50, fp_sws64_la50, tp_sws64_la50, fn_sws64_la50 = 93215, 5435, 15321, 6104
err_sws64_la50 = calculate_error_rate(fp_sws64_la50, fn_sws64_la50, tp_sws64_la50, tn_sws64_la50)
acc_sws64_la50 = calculate_accuracy(fp_sws64_la50, fn_sws64_la50, tp_sws64_la50, tn_sws64_la50)
rec_sws64_la50 = calculate_recall(fn_sws64_la50, tp_sws64_la50)
spec_sws64_la50 = calculate_specificity(fp_sws64_la50, tn_sws64_la50)
prec_sws64_la50 = calculate_precision(tp_sws64_la50, fp_sws64_la50)

# la = 100
tn_sws64_la100, fp_sws64_la100, tp_sws64_la100, fn_sws64_la100 = 90518, 5332, 12615, 8810
err_sws64_la100 = calculate_error_rate(fp_sws64_la100, fn_sws64_la100, tp_sws64_la100, tn_sws64_la100)
acc_sws64_la100 = calculate_accuracy(fp_sws64_la100, fn_sws64_la100, tp_sws64_la100, tn_sws64_la100)
rec_sws64_la100 = calculate_recall(fn_sws64_la100, tp_sws64_la100)
spec_sws64_la100 = calculate_specificity(fp_sws64_la100, tn_sws64_la100)
prec_sws64_la100 = calculate_precision(tp_sws64_la100, fp_sws64_la100)

# la = 150
tn_sws64_la150, fp_sws64_la150, tp_sws64_la150, fn_sws64_la150 = 87944, 5106, 10229, 11196
err_sws64_la150 = calculate_error_rate(fp_sws64_la150, fn_sws64_la150, tp_sws64_la150, tn_sws64_la150)
acc_sws64_la150 = calculate_accuracy(fp_sws64_la150, fn_sws64_la150, tp_sws64_la150, tn_sws64_la150)
rec_sws64_la150 = calculate_recall(fn_sws64_la150, tp_sws64_la150)
spec_sws64_la150 = calculate_specificity(fp_sws64_la150, tn_sws64_la150)
prec_sws64_la150 = calculate_precision(tp_sws64_la150, fp_sws64_la150)

# la = 200
tn_sws64_la200, fp_sws64_la200, tp_sws64_la200, fn_sws64_la200 = 84874, 5376, 8573, 12852
err_sws64_la200 = calculate_error_rate(fp_sws64_la200, fn_sws64_la200, tp_sws64_la200, tn_sws64_la200)
acc_sws64_la200 = calculate_accuracy(fp_sws64_la200, fn_sws64_la200, tp_sws64_la200, tn_sws64_la200)
rec_sws64_la200 = calculate_recall(fn_sws64_la200, tp_sws64_la200)
spec_sws64_la200 = calculate_specificity(fp_sws64_la200, tn_sws64_la200)
prec_sws64_la200 = calculate_precision(tp_sws64_la200, fp_sws64_la200)

# %%
base_path = '/home/lakshya/research/bes_edgeml_models/elm_classification/outputs'

# %% [markdown]
# ### Plots

# %%
# error rate
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
error_rates = np.array(
    [
        [err_sws8_la0, err_sws8_la50, err_sws8_la100, err_sws8_la150, err_sws8_la200],
        [err_sws16_la0, err_sws16_la50, err_sws16_la100, err_sws16_la150, err_sws16_la200],
        # [err_sws16_la0_rnn, err_sws16_la50_rnn, err_sws16_la100_rnn, err_sws16_la150_rnn, err_sws16_la200_rnn],
        [err_sws32_la0, err_sws32_la50, err_sws32_la100, err_sws32_la150, err_sws32_la200],
        # [err_sws32_la0_rnn, err_sws32_la50_rnn, err_sws32_la100_rnn, err_sws32_la150_rnn, err_sws32_la200_rnn],
        [err_sws64_la0, err_sws64_la50, err_sws64_la100, err_sws64_la150, err_sws64_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, error_rates, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Error rates (LSTM AE)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'lstm_ae_error_rate_wavelet_data.png'), dpi=120)
plt.show()

# %%
# # error rate
# la = np.array([0, 50, 100, 150, 200])
# sws = np.array([8, 16, 32, 64])
# X, Y = np.meshgrid(la, sws)
# error_rates = np.array(
#     [
#         [err_sws8_la0, err_sws8_la50, err_sws8_la100, err_sws8_la150, err_sws8_la200],
#         # [err_sws16_la0, err_sws16_la50, err_sws16_la100, err_sws16_la150, err_sws16_la200],
#         [err_sws16_la0_rnn, err_sws16_la50_rnn, err_sws16_la100_rnn, err_sws16_la150_rnn, err_sws16_la200_rnn],
#         # [err_sws32_la0, err_sws32_la50, err_sws32_la100, err_sws32_la150, err_sws32_la200],
#         [err_sws32_la0_rnn, err_sws32_la50_rnn, err_sws32_la100_rnn, err_sws32_la150_rnn, err_sws32_la200_rnn],
#         [err_sws64_la0, err_sws64_la50, err_sws64_la100, err_sws64_la150, err_sws64_la200]
#     ]
# )
# plt.figure(figsize=(6, 4), dpi=120)
# plt.contourf(X, Y, error_rates, 20, alpha=0.5, cmap='cubehelix')
# plt.xlabel('Label look ahead')
# plt.ylabel('Signal window size')
# plt.title('Error rates (raw)')
# plt.colorbar()
# plt.tight_layout()
# plt.savefig(os.path.join(base_path, 'error_rate_raw_data.png'), dpi=120)
# plt.show()

# %%
# accuracy
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
accuracy = np.array(
    [
        [acc_sws8_la0, acc_sws8_la50, acc_sws8_la100, acc_sws8_la150, acc_sws8_la200],
        [acc_sws16_la0, acc_sws16_la50, acc_sws16_la100, acc_sws16_la150, acc_sws16_la200],
        # [acc_sws16_la0_rnn, acc_sws16_la50_rnn, acc_sws16_la100_rnn, acc_sws16_la150_rnn, acc_sws16_la200_rnn],
        [acc_sws32_la0, acc_sws32_la50, acc_sws32_la100, acc_sws32_la150, acc_sws32_la200],
        # [acc_sws32_la0_rnn, acc_sws32_la50_rnn, acc_sws32_la100_rnn, acc_sws32_la150_rnn, acc_sws32_la200_rnn],
        [acc_sws64_la0, acc_sws64_la50, acc_sws64_la100, acc_sws64_la150, acc_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, accuracy, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Accuracy (LSTM AE)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'lstm_ae_accuracy_wavelet_data.png'), dpi=120)
plt.show()

# %%
# accuracy
# la = np.array([0, 50, 100, 150, 200])
# sws = np.array([8, 16, 32, 64])
# X, Y = np.meshgrid(la, sws)
# accuracy = np.array(
#     [
#         [acc_sws8_la0, acc_sws8_la50, acc_sws8_la100, acc_sws8_la150, acc_sws8_la200],
#         # [acc_sws16_la0, acc_sws16_la50, acc_sws16_la100, acc_sws16_la150, acc_sws16_la200],
#         [acc_sws16_la0_rnn, acc_sws16_la50_rnn, acc_sws16_la100_rnn, acc_sws16_la150_rnn, acc_sws16_la200_rnn],
#         # [acc_sws32_la0, acc_sws32_la50, acc_sws32_la100, acc_sws32_la150, acc_sws32_la200],
#         [acc_sws32_la0_rnn, acc_sws32_la50_rnn, acc_sws32_la100_rnn, acc_sws32_la150_rnn, acc_sws32_la200_rnn],
#         [acc_sws64_la0, acc_sws64_la50, acc_sws64_la100, acc_sws64_la150, acc_sws64_la200]
#     ]
# )
# plt.figure(figsize=(6, 4), dpi=120)
# plt.contourf(X, Y, accuracy, 20, alpha=0.5, cmap='cubehelix')
# plt.xlabel('Label look ahead')
# plt.ylabel('Signal window size')
# plt.title('Accuracy (raw)')
# plt.colorbar()
# plt.tight_layout()
# plt.savefig(os.path.join(base_path, 'accuracy_raw_data.png'), dpi=120)
# plt.show()

# %%
# recall
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
recall = np.array(
    [
        [rec_sws8_la0, rec_sws8_la50, rec_sws8_la100, rec_sws8_la150, rec_sws8_la200],
        [rec_sws16_la0, rec_sws16_la50, rec_sws16_la100, rec_sws16_la150, rec_sws16_la200],
        # [rec_sws16_la0_rnn, rec_sws16_la50_rnn, rec_sws16_la100_rnn, rec_sws16_la150_rnn, rec_sws16_la200_rnn],
        [rec_sws32_la0, rec_sws32_la50, rec_sws32_la100, rec_sws32_la150, rec_sws32_la200],
        # [rec_sws32_la0_rnn, rec_sws32_la50_rnn, rec_sws32_la100_rnn, rec_sws32_la150_rnn, rec_sws32_la200_rnn],
        [rec_sws64_la0, rec_sws64_la50, rec_sws64_la100, rec_sws64_la150, rec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, recall, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Recall (LSTM AE)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'lstm_ae_recall_wavelet_data.png'), dpi=120)
plt.show()

# %%
# # recall
# la = np.array([0, 50, 100, 150, 200])
# sws = np.array([8, 16, 32, 64])
# X, Y = np.meshgrid(la, sws)
# recall = np.array(
#     [
#         [rec_sws8_la0, rec_sws8_la50, rec_sws8_la100, rec_sws8_la150, rec_sws8_la200],
#         # [rec_sws16_la0, rec_sws16_la50, rec_sws16_la100, rec_sws16_la150, rec_sws16_la200],
#         [rec_sws16_la0_rnn, rec_sws16_la50_rnn, rec_sws16_la100_rnn, rec_sws16_la150_rnn, rec_sws16_la200_rnn],
#         # [rec_sws32_la0, rec_sws32_la50, rec_sws32_la100, rec_sws32_la150, rec_sws32_la200],
#         [rec_sws32_la0_rnn, rec_sws32_la50_rnn, rec_sws32_la100_rnn, rec_sws32_la150_rnn, rec_sws32_la200_rnn],
#         [rec_sws64_la0, rec_sws64_la50, rec_sws64_la100, rec_sws64_la150, rec_sws64_la200]
#     ]
# )
# plt.figure(figsize=(6, 4), dpi=120)
# plt.contourf(X, Y, recall, 20, alpha=0.5, cmap='cubehelix')
# plt.xlabel('Label look ahead')
# plt.ylabel('Signal window size')
# plt.title('Recall (rnn)')
# plt.colorbar()
# plt.tight_layout()
# plt.savefig(os.path.join(base_path, 'recall_raw_data.png'), dpi=120)
# plt.show()

# %%
# precision
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
precision = np.array(
    [
        [prec_sws8_la0, prec_sws8_la50, prec_sws8_la100, prec_sws8_la150, prec_sws8_la200],
        [prec_sws16_la0, prec_sws16_la50, prec_sws16_la100, prec_sws16_la150, prec_sws16_la200],
        # [prec_sws16_la0_rnn, prec_sws16_la50_rnn, prec_sws16_la100_rnn, prec_sws16_la150_rnn, prec_sws16_la200_rnn],
        [prec_sws32_la0, prec_sws32_la50, prec_sws32_la100, prec_sws32_la150, prec_sws32_la200],
        # [prec_sws32_la0_rnn, prec_sws32_la50_rnn, prec_sws32_la100_rnn, prec_sws32_la150_rnn, prec_sws32_la200_rnn],
        [prec_sws64_la0, prec_sws64_la50, prec_sws64_la100, prec_sws64_la150, prec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, precision, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Precision (LSTM AE)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'lstm_ae_precision_wavelet_data.png'), dpi=120)
plt.show()

# %%
# precision
# la = np.array([0, 50, 100, 150, 200])
# sws = np.array([8, 16, 32, 64])
# X, Y = np.meshgrid(la, sws)
# precision = np.array(
#     [
#         [prec_sws8_la0, prec_sws8_la50, prec_sws8_la100, prec_sws8_la150, prec_sws8_la200],
#         # [prec_sws16_la0, prec_sws16_la50, prec_sws16_la100, prec_sws16_la150, prec_sws16_la200],
#         [prec_sws16_la0_rnn, prec_sws16_la50_rnn, prec_sws16_la100_rnn, prec_sws16_la150_rnn, prec_sws16_la200_rnn],
#         # [prec_sws32_la0, prec_sws32_la50, prec_sws32_la100, prec_sws32_la150, prec_sws32_la200],
#         [prec_sws32_la0_rnn, prec_sws32_la50_rnn, prec_sws32_la100_rnn, prec_sws32_la150_rnn, prec_sws32_la200_rnn],
#         [prec_sws64_la0, prec_sws64_la50, prec_sws64_la100, prec_sws64_la150, prec_sws64_la200]
#     ]
# )
# plt.figure(figsize=(6, 4), dpi=120)
# plt.contourf(X, Y, precision, 20, alpha=0.5, cmap='cubehelix')
# plt.xlabel('Label look ahead')
# plt.ylabel('Signal window size')
# plt.title('Precision (raw)')
# plt.colorbar()
# plt.tight_layout()
# plt.savefig(os.path.join(base_path, 'precision_raw_data.png'), dpi=120)
# plt.show()

# %%
# specificity
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
spec = np.array(
    [
        [spec_sws8_la0, spec_sws8_la50, spec_sws8_la100, spec_sws8_la150, spec_sws8_la200],
        [spec_sws16_la0, spec_sws16_la50, spec_sws16_la100, spec_sws16_la150, spec_sws16_la200],
        # [spec_sws16_la0_rnn, spec_sws16_la50_rnn, spec_sws16_la100_rnn, spec_sws16_la150_rnn, spec_sws16_la200_rnn],
        [spec_sws32_la0, spec_sws32_la50, spec_sws32_la100, spec_sws32_la150, spec_sws32_la200],
        # [spec_sws32_la0_rnn, spec_sws32_la50_rnn, spec_sws32_la100_rnn, spec_sws32_la150_rnn, spec_sws32_la200_rnn],
        [spec_sws64_la0, spec_sws64_la50, spec_sws64_la100, spec_sws64_la150, spec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, spec, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Specificity (TNR) (LSTM AE)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'lstm_ae_pecificity_wavelet_data.png'), dpi=120)
plt.show()

# %%
# # specificity
# la = np.array([0, 50, 100, 150, 200])
# sws = np.array([8, 16, 32, 64])
# X, Y = np.meshgrid(la, sws)
# spec = np.array(
#     [
#         [spec_sws8_la0, spec_sws8_la50, spec_sws8_la100, spec_sws8_la150, spec_sws8_la200],
#         # [spec_sws16_la0, spec_sws16_la50, spec_sws16_la100, spec_sws16_la150, spec_sws16_la200],
#         [spec_sws16_la0_rnn, spec_sws16_la50_rnn, spec_sws16_la100_rnn, spec_sws16_la150_rnn, spec_sws16_la200_rnn],
#         # [spec_sws32_la0, spec_sws32_la50, spec_sws32_la100, spec_sws32_la150, spec_sws32_la200],
#         [spec_sws32_la0_rnn, spec_sws32_la50_rnn, spec_sws32_la100_rnn, spec_sws32_la150_rnn, spec_sws32_la200_rnn],
#         [spec_sws64_la0, spec_sws64_la50, spec_sws64_la100, spec_sws64_la150, spec_sws64_la200]
#     ]
# )
# plt.figure(figsize=(6, 4), dpi=120)
# plt.contourf(X, Y, spec, 20, alpha=0.5, cmap='cubehelix')
# plt.xlabel('Label look ahead')
# plt.ylabel('Signal window size')
# plt.title('Specificity (TNR) (raw)')
# plt.colorbar()
# plt.tight_layout()
# plt.savefig(os.path.join(base_path, 'specificity_raw_data.png'), dpi=120)
# plt.show()

# %% [markdown]
# ## CNN Model

# %% [markdown]
# ### CNN (sws=8)

# %%
# la = 0
tn_sws8_la0, fp_sws8_la0, tp_sws8_la0, fn_sws8_la0 = 103008, 1523, 14723, 6702
err_sws8_la0 = calculate_error_rate(fp_sws8_la0, fn_sws8_la0, tp_sws8_la0, tn_sws8_la0)
acc_sws8_la0 = calculate_accuracy(fp_sws8_la0, fn_sws8_la0, tp_sws8_la0, tn_sws8_la0)
rec_sws8_la0 = calculate_recall(fn_sws8_la0, tp_sws8_la0)
spec_sws8_la0 = calculate_specificity(fp_sws8_la0, tn_sws8_la0)
prec_sws8_la0 = calculate_precision(tp_sws8_la0, fp_sws8_la0)

# la = 50
tn_sws8_la50, fp_sws8_la50, tp_sws8_la50, fn_sws8_la50 = 101053, 678, 14186, 7239
err_sws8_la50 = calculate_error_rate(fp_sws8_la50, fn_sws8_la50, tp_sws8_la50, tn_sws8_la50)
acc_sws8_la50 = calculate_accuracy(fp_sws8_la50, fn_sws8_la50, tp_sws8_la50, tn_sws8_la50)
rec_sws8_la50 = calculate_recall(fn_sws8_la50, tp_sws8_la50)
spec_sws8_la50 = calculate_specificity(fp_sws8_la50, tn_sws8_la50)
prec_sws8_la50 = calculate_precision(tp_sws8_la50, fp_sws8_la50)

# la = 100
tn_sws8_la100, fp_sws8_la100, tp_sws8_la100, fn_sws8_la100 = 100663, 171, 11717, 7805
err_sws8_la100 = calculate_error_rate(fp_sws8_la100, fn_sws8_la100, tp_sws8_la100, tn_sws8_la100)
acc_sws8_la100 = calculate_accuracy(fp_sws8_la100, fn_sws8_la100, tp_sws8_la100, tn_sws8_la100)
rec_sws8_la100 = calculate_recall(fn_sws8_la100, tp_sws8_la100)
spec_sws8_la100 = calculate_specificity(fp_sws8_la100, tn_sws8_la100)
prec_sws8_la100 = calculate_precision(tp_sws8_la100, fp_sws8_la100)

# la = 150
tn_sws8_la150, fp_sws8_la150, tp_sws8_la150, fn_sws8_la150 = 100694, 140, 9433, 7289
err_sws8_la150 = calculate_error_rate(fp_sws8_la150, fn_sws8_la150, tp_sws8_la150, tn_sws8_la150)
acc_sws8_la150 = calculate_accuracy(fp_sws8_la150, fn_sws8_la150, tp_sws8_la150, tn_sws8_la150)
rec_sws8_la150 = calculate_recall(fn_sws8_la150, tp_sws8_la150)
spec_sws8_la150 = calculate_specificity(fp_sws8_la150, tn_sws8_la150)
prec_sws8_la150 = calculate_precision(tp_sws8_la150, fp_sws8_la150)

# la = 200
tn_sws8_la200, fp_sws8_la200, tp_sws8_la200, fn_sws8_la200 = 100834, 0, 2675, 11247
err_sws8_la200 = calculate_error_rate(fp_sws8_la200, fn_sws8_la200, tp_sws8_la200, tn_sws8_la200)
acc_sws8_la200 = calculate_accuracy(fp_sws8_la200, fn_sws8_la200, tp_sws8_la200, tn_sws8_la200)
rec_sws8_la200 = calculate_recall(fn_sws8_la200, tp_sws8_la200)
spec_sws8_la200 = calculate_specificity(fp_sws8_la200, tn_sws8_la200)
prec_sws8_la200 = calculate_precision(tp_sws8_la200, fp_sws8_la200)

# %% [markdown]
# ### CNN (sws=16)

# %%
# la = 0
tn_sws16_la0, fp_sws16_la0, tp_sws16_la0, fn_sws16_la0 = 100672, 3411, 16718, 4707
err_sws16_la0 = calculate_error_rate(fp_sws16_la0, fn_sws16_la0, tp_sws16_la0, tn_sws16_la0)
acc_sws16_la0 = calculate_accuracy(fp_sws16_la0, fn_sws16_la0, tp_sws16_la0, tn_sws16_la0)
rec_sws16_la0 = calculate_recall(fn_sws16_la0, tp_sws16_la0)
spec_sws16_la0 = calculate_specificity(fp_sws16_la0, tn_sws16_la0)
prec_sws16_la0 = calculate_precision(tp_sws16_la0, fp_sws16_la0)

# la = 50
tn_sws16_la50, fp_sws16_la50, tp_sws16_la50, fn_sws16_la50 = 100740, 543, 14769, 6656
err_sws16_la50 = calculate_error_rate(fp_sws16_la50, fn_sws16_la50, tp_sws16_la50, tn_sws16_la50)
acc_sws16_la50 = calculate_accuracy(fp_sws16_la50, fn_sws16_la50, tp_sws16_la50, tn_sws16_la50)
rec_sws16_la50 = calculate_recall(fn_sws16_la50, tp_sws16_la50)
spec_sws16_la50 = calculate_specificity(fp_sws16_la50, tn_sws16_la50)
prec_sws16_la50 = calculate_precision(tp_sws16_la50, fp_sws16_la50)

# la = 100
tn_sws16_la100, fp_sws16_la100, tp_sws16_la100, fn_sws16_la100 = 100500, 334, 13227, 5847
err_sws16_la100 = calculate_error_rate(fp_sws16_la100, fn_sws16_la100, tp_sws16_la100, tn_sws16_la100)
acc_sws16_la100 = calculate_accuracy(fp_sws16_la100, fn_sws16_la100, tp_sws16_la100, tn_sws16_la100)
rec_sws16_la100 = calculate_recall(fn_sws16_la100, tp_sws16_la100)
spec_sws16_la100 = calculate_specificity(fp_sws16_la100, tn_sws16_la100)
prec_sws16_la100 = calculate_precision(tp_sws16_la100, fp_sws16_la100)

# la = 150
tn_sws16_la150, fp_sws16_la150, tp_sws16_la150, fn_sws16_la150 = 99667, 1167, 11265, 5009
err_sws16_la150 = calculate_error_rate(fp_sws16_la150, fn_sws16_la150, tp_sws16_la150, tn_sws16_la150)
acc_sws16_la150 = calculate_accuracy(fp_sws16_la150, fn_sws16_la150, tp_sws16_la150, tn_sws16_la150)
rec_sws16_la150 = calculate_recall(fn_sws16_la150, tp_sws16_la150)
spec_sws16_la150 = calculate_specificity(fp_sws16_la150, tn_sws16_la150)
prec_sws16_la150 = calculate_precision(tp_sws16_la150, fp_sws16_la150)

# la = 200
tn_sws16_la200, fp_sws16_la200, tp_sws16_la200, fn_sws16_la200 = 100687, 140, 7442, 6039
err_sws16_la200 = calculate_error_rate(fp_sws16_la200, fn_sws16_la200, tp_sws16_la200, tn_sws16_la200)
acc_sws16_la200 = calculate_accuracy(fp_sws16_la200, fn_sws16_la200, tp_sws16_la200, tn_sws16_la200)
rec_sws16_la200 = calculate_recall(fn_sws16_la200, tp_sws16_la200)
spec_sws16_la200 = calculate_specificity(fp_sws16_la200, tn_sws16_la200)
prec_sws16_la200 = calculate_precision(tp_sws16_la200, fp_sws16_la200)

# %% [markdown]
# ### CNN (sws=32)

# %%
# la = 0
tn_sws32_la0, fp_sws32_la0, tp_sws32_la0, fn_sws32_la0 = 101246, 1941, 16383, 5042
err_sws32_la0 = calculate_error_rate(fp_sws32_la0, fn_sws32_la0, tp_sws32_la0, tn_sws32_la0)
acc_sws32_la0 = calculate_accuracy(fp_sws32_la0, fn_sws32_la0, tp_sws32_la0, tn_sws32_la0)
rec_sws32_la0 = calculate_recall(fn_sws32_la0, tp_sws32_la0)
spec_sws32_la0 = calculate_specificity(fp_sws32_la0, tn_sws32_la0)
prec_sws32_la0 = calculate_precision(tp_sws32_la0, fp_sws32_la0)

# la = 50
tn_sws32_la50, fp_sws32_la50, tp_sws32_la50, fn_sws32_la50 = 100436, 398, 14949, 6029
err_sws32_la50 = calculate_error_rate(fp_sws32_la50, fn_sws32_la50, tp_sws32_la50, tn_sws32_la50)
acc_sws32_la50 = calculate_accuracy(fp_sws32_la50, fn_sws32_la50, tp_sws32_la50, tn_sws32_la50)
rec_sws32_la50 = calculate_recall(fn_sws32_la50, tp_sws32_la50)
spec_sws32_la50 = calculate_specificity(fp_sws32_la50, tn_sws32_la50)
prec_sws32_la50 = calculate_precision(tp_sws32_la50, fp_sws32_la50)

# la = 100
tn_sws32_la100, fp_sws32_la100, tp_sws32_la100, fn_sws32_la100 = 100375, 459, 13087, 5091
err_sws32_la100 = calculate_error_rate(fp_sws32_la100, fn_sws32_la100, tp_sws32_la100, tn_sws32_la100)
acc_sws32_la100 = calculate_accuracy(fp_sws32_la100, fn_sws32_la100, tp_sws32_la100, tn_sws32_la100)
rec_sws32_la100 = calculate_recall(fn_sws32_la100, tp_sws32_la100)
spec_sws32_la100 = calculate_specificity(fp_sws32_la100, tn_sws32_la100)
prec_sws32_la100 = calculate_precision(tp_sws32_la100, fp_sws32_la100)

# la = 150
tn_sws32_la150, fp_sws32_la150, tp_sws32_la150, fn_sws32_la150 = 100558, 276, 10525, 4853
err_sws32_la150 = calculate_error_rate(fp_sws32_la150, fn_sws32_la150, tp_sws32_la150, tn_sws32_la150)
acc_sws32_la150 = calculate_accuracy(fp_sws32_la150, fn_sws32_la150, tp_sws32_la150, tn_sws32_la150)
rec_sws32_la150 = calculate_recall(fn_sws32_la150, tp_sws32_la150)
spec_sws32_la150 = calculate_specificity(fp_sws32_la150, tn_sws32_la150)
prec_sws32_la150 = calculate_precision(tp_sws32_la150, fp_sws32_la150)

# la = 200
tn_sws32_la200, fp_sws32_la200, tp_sws32_la200, fn_sws32_la200 = 100636, 175, 7541, 5060
err_sws32_la200 = calculate_error_rate(fp_sws32_la200, fn_sws32_la200, tp_sws32_la200, tn_sws32_la200)
acc_sws32_la200 = calculate_accuracy(fp_sws32_la200, fn_sws32_la200, tp_sws32_la200, tn_sws32_la200)
rec_sws32_la200 = calculate_recall(fn_sws32_la200, tp_sws32_la200)
spec_sws32_la200 = calculate_specificity(fp_sws32_la200, tn_sws32_la200)
prec_sws32_la200 = calculate_precision(tp_sws32_la200, fp_sws32_la200)

# %% [markdown]
# ### CNN (sws=64)

# %%
# la = 0
tn_sws64_la0, fp_sws64_la0, tp_sws64_la0, fn_sws64_la0 = 99411, 1984, 18684, 2741
err_sws64_la0 = calculate_error_rate(fp_sws64_la0, fn_sws64_la0, tp_sws64_la0, tn_sws64_la0)
acc_sws64_la0 = calculate_accuracy(fp_sws64_la0, fn_sws64_la0, tp_sws64_la0, tn_sws64_la0)
rec_sws64_la0 = calculate_recall(fn_sws64_la0, tp_sws64_la0)
spec_sws64_la0 = calculate_specificity(fp_sws64_la0, tn_sws64_la0)
prec_sws64_la0 = calculate_precision(tp_sws64_la0, fp_sws64_la0)

# la = 50
tn_sws64_la50, fp_sws64_la50, tp_sws64_la50, fn_sws64_la50 = 99208, 1626, 16260, 2926
err_sws64_la50 = calculate_error_rate(fp_sws64_la50, fn_sws64_la50, tp_sws64_la50, tn_sws64_la50)
acc_sws64_la50 = calculate_accuracy(fp_sws64_la50, fn_sws64_la50, tp_sws64_la50, tn_sws64_la50)
rec_sws64_la50 = calculate_recall(fn_sws64_la50, tp_sws64_la50)
spec_sws64_la50 = calculate_specificity(fp_sws64_la50, tn_sws64_la50)
prec_sws64_la50 = calculate_precision(tp_sws64_la50, fp_sws64_la50)

# la = 100
tn_sws64_la100, fp_sws64_la100, tp_sws64_la100, fn_sws64_la100 = 99721, 1113, 13643, 2743
err_sws64_la100 = calculate_error_rate(fp_sws64_la100, fn_sws64_la100, tp_sws64_la100, tn_sws64_la100)
acc_sws64_la100 = calculate_accuracy(fp_sws64_la100, fn_sws64_la100, tp_sws64_la100, tn_sws64_la100)
rec_sws64_la100 = calculate_recall(fn_sws64_la100, tp_sws64_la100)
spec_sws64_la100 = calculate_specificity(fp_sws64_la100, tn_sws64_la100)
prec_sws64_la100 = calculate_precision(tp_sws64_la100, fp_sws64_la100)

# la = 150
tn_sws64_la150, fp_sws64_la150, tp_sws64_la150, fn_sws64_la150 = 99905, 924, 10905, 2686
err_sws64_la150 = calculate_error_rate(fp_sws64_la150, fn_sws64_la150, tp_sws64_la150, tn_sws64_la150)
acc_sws64_la150 = calculate_accuracy(fp_sws64_la150, fn_sws64_la150, tp_sws64_la150, tn_sws64_la150)
rec_sws64_la150 = calculate_recall(fn_sws64_la150, tp_sws64_la150)
spec_sws64_la150 = calculate_specificity(fp_sws64_la150, tn_sws64_la150)
prec_sws64_la150 = calculate_precision(tp_sws64_la150, fp_sws64_la150)

# la = 200
tn_sws64_la200, fp_sws64_la200, tp_sws64_la200, fn_sws64_la200 = 100459, 299, 7566, 3296
err_sws64_la200 = calculate_error_rate(fp_sws64_la200, fn_sws64_la200, tp_sws64_la200, tn_sws64_la200)
acc_sws64_la200 = calculate_accuracy(fp_sws64_la200, fn_sws64_la200, tp_sws64_la200, tn_sws64_la200)
rec_sws64_la200 = calculate_recall(fn_sws64_la200, tp_sws64_la200)
spec_sws64_la200 = calculate_specificity(fp_sws64_la200, tn_sws64_la200)
prec_sws64_la200 = calculate_precision(tp_sws64_la200, fp_sws64_la200)

# %% [markdown]
# ### CNN (sws=128)

# %%
# la = 0
tn_sws128_la0, fp_sws128_la0, tp_sws128_la0, fn_sws128_la0 = 97631, 3203, 16026, 2376
err_sws128_la0 = calculate_error_rate(fp_sws128_la0, fn_sws128_la0, tp_sws128_la0, tn_sws128_la0)
acc_sws128_la0 = calculate_accuracy(fp_sws128_la0, fn_sws128_la0, tp_sws128_la0, tn_sws128_la0)
rec_sws128_la0 = calculate_recall(fn_sws128_la0, tp_sws128_la0)
spec_sws128_la0 = calculate_specificity(fp_sws128_la0, tn_sws128_la0)
prec_sws128_la0 = calculate_precision(tp_sws128_la0, fp_sws128_la0)

# la = 50
tn_sws128_la50, fp_sws128_la50, tp_sws128_la50, fn_sws128_la50 = 95081, 5753, 14794, 808
err_sws128_la50 = calculate_error_rate(fp_sws128_la50, fn_sws128_la50, tp_sws128_la50, tn_sws128_la50)
acc_sws128_la50 = calculate_accuracy(fp_sws128_la50, fn_sws128_la50, tp_sws128_la50, tn_sws128_la50)
rec_sws128_la50 = calculate_recall(fn_sws128_la50, tp_sws128_la50)
spec_sws128_la50 = calculate_specificity(fp_sws128_la50, tn_sws128_la50)
prec_sws128_la50 = calculate_precision(tp_sws128_la50, fp_sws128_la50)

# la = 100
tn_sws128_la100, fp_sws128_la100, tp_sws128_la100, fn_sws128_la100 = 98424, 2391, 11927, 894
err_sws128_la100 = calculate_error_rate(fp_sws128_la100, fn_sws128_la100, tp_sws128_la100, tn_sws128_la100)
acc_sws128_la100 = calculate_accuracy(fp_sws128_la100, fn_sws128_la100, tp_sws128_la100, tn_sws128_la100)
rec_sws128_la100 = calculate_recall(fn_sws128_la100, tp_sws128_la100)
spec_sws128_la100 = calculate_specificity(fp_sws128_la100, tn_sws128_la100)
prec_sws128_la100 = calculate_precision(tp_sws128_la100, fp_sws128_la100)

# la = 150
tn_sws128_la150, fp_sws128_la150, tp_sws128_la150, fn_sws128_la150 = 99075, 1623, 8956, 1182
err_sws128_la150 = calculate_error_rate(fp_sws128_la150, fn_sws128_la150, tp_sws128_la150, tn_sws128_la150)
acc_sws128_la150 = calculate_accuracy(fp_sws128_la150, fn_sws128_la150, tp_sws128_la150, tn_sws128_la150)
rec_sws128_la150 = calculate_recall(fn_sws128_la150, tp_sws128_la150)
spec_sws128_la150 = calculate_specificity(fp_sws128_la150, tn_sws128_la150)
prec_sws128_la150 = calculate_precision(tp_sws128_la150, fp_sws128_la150)

# la = 200
tn_sws128_la200, fp_sws128_la200, tp_sws128_la200, fn_sws128_la200 = 100243, 13, 2849, 4931
err_sws128_la200 = calculate_error_rate(fp_sws128_la200, fn_sws128_la200, tp_sws128_la200, tn_sws128_la200)
acc_sws128_la200 = calculate_accuracy(fp_sws128_la200, fn_sws128_la200, tp_sws128_la200, tn_sws128_la200)
rec_sws128_la200 = calculate_recall(fn_sws128_la200, tp_sws128_la200)
spec_sws128_la200 = calculate_specificity(fp_sws128_la200, tn_sws128_la200)
prec_sws128_la200 = calculate_precision(tp_sws128_la200, fp_sws128_la200)

# %% [markdown]
# ### CNN (sws=256)

# %%
# la = 0
tn_sws256_la0, fp_sws256_la0, tp_sws256_la0, fn_sws256_la0 = 90187, 10595, 10423, 863
err_sws256_la0 = calculate_error_rate(fp_sws256_la0, fn_sws256_la0, tp_sws256_la0, tn_sws256_la0)
acc_sws256_la0 = calculate_accuracy(fp_sws256_la0, fn_sws256_la0, tp_sws256_la0, tn_sws256_la0)
rec_sws256_la0 = calculate_recall(fn_sws256_la0, tp_sws256_la0)
spec_sws256_la0 = calculate_specificity(fp_sws256_la0, tn_sws256_la0)
prec_sws256_la0 = calculate_precision(tp_sws256_la0, fp_sws256_la0)

# la = 50
tn_sws256_la50, fp_sws256_la50, tp_sws256_la50, fn_sws256_la50 = 90761, 9740, 8207, 560
err_sws256_la50 = calculate_error_rate(fp_sws256_la50, fn_sws256_la50, tp_sws256_la50, tn_sws256_la50)
acc_sws256_la50 = calculate_accuracy(fp_sws256_la50, fn_sws256_la50, tp_sws256_la50, tn_sws256_la50)
rec_sws256_la50 = calculate_recall(fn_sws256_la50, tp_sws256_la50)
spec_sws256_la50 = calculate_specificity(fp_sws256_la50, tn_sws256_la50)
prec_sws256_la50 = calculate_precision(tp_sws256_la50, fp_sws256_la50)

# la = 100
tn_sws256_la100, fp_sws256_la100, tp_sws256_la100, fn_sws256_la100 = 90264, 9598, 6416, 190
err_sws256_la100 = calculate_error_rate(fp_sws256_la100, fn_sws256_la100, tp_sws256_la100, tn_sws256_la100)
acc_sws256_la100 = calculate_accuracy(fp_sws256_la100, fn_sws256_la100, tp_sws256_la100, tn_sws256_la100)
rec_sws256_la100 = calculate_recall(fn_sws256_la100, tp_sws256_la100)
spec_sws256_la100 = calculate_specificity(fp_sws256_la100, tn_sws256_la100)
prec_sws256_la100 = calculate_precision(tp_sws256_la100, fp_sws256_la100)

# la = 150
tn_sws256_la150, fp_sws256_la150, tp_sws256_la150, fn_sws256_la150 = 90668, 8358, 4222, 420
err_sws256_la150 = calculate_error_rate(fp_sws256_la150, fn_sws256_la150, tp_sws256_la150, tn_sws256_la150)
acc_sws256_la150 = calculate_accuracy(fp_sws256_la150, fn_sws256_la150, tp_sws256_la150, tn_sws256_la150)
rec_sws256_la150 = calculate_recall(fn_sws256_la150, tp_sws256_la150)
spec_sws256_la150 = calculate_specificity(fp_sws256_la150, tn_sws256_la150)
prec_sws256_la150 = calculate_precision(tp_sws256_la150, fp_sws256_la150)

# la = 200
tn_sws256_la200, fp_sws256_la200, tp_sws256_la200, fn_sws256_la200 = 90621, 7094, 2935, 218
err_sws256_la200 = calculate_error_rate(fp_sws256_la200, fn_sws256_la200, tp_sws256_la200, tn_sws256_la200)
acc_sws256_la200 = calculate_accuracy(fp_sws256_la200, fn_sws256_la200, tp_sws256_la200, tn_sws256_la200)
rec_sws256_la200 = calculate_recall(fn_sws256_la200, tp_sws256_la200)
spec_sws256_la200 = calculate_specificity(fp_sws256_la200, tn_sws256_la200)
prec_sws256_la200 = calculate_precision(tp_sws256_la200, fp_sws256_la200)

# %% [markdown]
# ### Plots (no extended sws)

# %%
# error rate
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
error_rates = np.array(
    [
        [err_sws8_la0, err_sws8_la50, err_sws8_la100, err_sws8_la150, err_sws8_la200],
        [err_sws16_la0, err_sws16_la50, err_sws16_la100, err_sws16_la150, err_sws16_la200],
        [err_sws32_la0, err_sws32_la50, err_sws32_la100, err_sws32_la150, err_sws32_la200],
        [err_sws64_la0, err_sws64_la50, err_sws64_la100, err_sws64_la150, err_sws64_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, error_rates, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Error rates (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_error_rate_wavelet_data.png'), dpi=120)
plt.show()

# %%
# accuracy
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
accuracy = np.array(
    [
        [acc_sws8_la0, acc_sws8_la50, acc_sws8_la100, acc_sws8_la150, acc_sws8_la200],
        [acc_sws16_la0, acc_sws16_la50, acc_sws16_la100, acc_sws16_la150, acc_sws16_la200],
        [acc_sws32_la0, acc_sws32_la50, acc_sws32_la100, acc_sws32_la150, acc_sws32_la200],
        [acc_sws64_la0, acc_sws64_la50, acc_sws64_la100, acc_sws64_la150, acc_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, accuracy, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Accuracy (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_accuracy_wavelet_data.png'), dpi=120)
plt.show()

# %%
# recall
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
recall = np.array(
    [
        [rec_sws8_la0, rec_sws8_la50, rec_sws8_la100, rec_sws8_la150, rec_sws8_la200],
        [rec_sws16_la0, rec_sws16_la50, rec_sws16_la100, rec_sws16_la150, rec_sws16_la200],
        [rec_sws32_la0, rec_sws32_la50, rec_sws32_la100, rec_sws32_la150, rec_sws32_la200],
        [rec_sws64_la0, rec_sws64_la50, rec_sws64_la100, rec_sws64_la150, rec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, recall, 20, alpha=0.6, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Recall (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_recall_wavelet_data.png'), dpi=120)
plt.show()

# %%
# precision
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
precision = np.array(
    [
        [prec_sws8_la0, prec_sws8_la50, prec_sws8_la100, prec_sws8_la150, prec_sws8_la200],
        [prec_sws16_la0, prec_sws16_la50, prec_sws16_la100, prec_sws16_la150, prec_sws16_la200],
        [prec_sws32_la0, prec_sws32_la50, prec_sws32_la100, prec_sws32_la150, prec_sws32_la200],
        [prec_sws64_la0, prec_sws64_la50, prec_sws64_la100, prec_sws64_la150, prec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, precision, 20, alpha=0.6, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Precision (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_precision_wavelet_data.png'), dpi=120)
plt.show()

# %%
# specificity
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
spec = np.array(
    [
        [spec_sws8_la0, spec_sws8_la50, spec_sws8_la100, spec_sws8_la150, spec_sws8_la200],
        [spec_sws16_la0, spec_sws16_la50, spec_sws16_la100, spec_sws16_la150, spec_sws16_la200],
        [spec_sws32_la0, spec_sws32_la50, spec_sws32_la100, spec_sws32_la150, spec_sws32_la200],
        [spec_sws64_la0, spec_sws64_la50, spec_sws64_la100, spec_sws64_la150, spec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, spec, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Specificity (TNR) (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_specificity_wavelet_data.png'), dpi=120)
plt.show()

# %% [markdown]
# ### Plots (extended sws)

# %%
# error rate
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
error_rates = np.array(
    [
        [err_sws8_la0, err_sws8_la50, err_sws8_la100, err_sws8_la150, err_sws8_la200],
        [err_sws16_la0, err_sws16_la50, err_sws16_la100, err_sws16_la150, err_sws16_la200],
        [err_sws32_la0, err_sws32_la50, err_sws32_la100, err_sws32_la150, err_sws32_la200],
        [err_sws64_la0, err_sws64_la50, err_sws64_la100, err_sws64_la150, err_sws64_la200],
        [err_sws128_la0, err_sws128_la50, err_sws128_la100, err_sws128_la150, err_sws128_la200],
        [err_sws256_la0, err_sws256_la50, err_sws256_la100, err_sws256_la150, err_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, error_rates, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Error rates (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_error_rate_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %%
# accuracy
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
accuracy = np.array(
    [
        [acc_sws8_la0, acc_sws8_la50, acc_sws8_la100, acc_sws8_la150, acc_sws8_la200],
        [acc_sws16_la0, acc_sws16_la50, acc_sws16_la100, acc_sws16_la150, acc_sws16_la200],
        [acc_sws32_la0, acc_sws32_la50, acc_sws32_la100, acc_sws32_la150, acc_sws32_la200],
        [acc_sws64_la0, acc_sws64_la50, acc_sws64_la100, acc_sws64_la150, acc_sws64_la200],
        [acc_sws128_la0, acc_sws128_la50, acc_sws128_la100, acc_sws128_la150, acc_sws128_la200],
        [acc_sws256_la0, acc_sws256_la50, acc_sws256_la100, acc_sws256_la150, acc_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, accuracy, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Accuracy (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_accuracy_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %%
# recall
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
recall = np.array(
    [
        [rec_sws8_la0, rec_sws8_la50, rec_sws8_la100, rec_sws8_la150, rec_sws8_la200],
        [rec_sws16_la0, rec_sws16_la50, rec_sws16_la100, rec_sws16_la150, rec_sws16_la200],
        [rec_sws32_la0, rec_sws32_la50, rec_sws32_la100, rec_sws32_la150, rec_sws32_la200],
        [rec_sws64_la0, rec_sws64_la50, rec_sws64_la100, rec_sws64_la150, rec_sws64_la200],
        [rec_sws128_la0, rec_sws128_la50, rec_sws128_la100, rec_sws128_la150, rec_sws128_la200],
        [rec_sws256_la0, rec_sws256_la50, rec_sws256_la100, rec_sws256_la150, rec_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, recall, 20, alpha=0.6, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Recall (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_recall_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %%
# precision
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
precision = np.array(
    [
        [prec_sws8_la0, prec_sws8_la50, prec_sws8_la100, prec_sws8_la150, prec_sws8_la200],
        [prec_sws16_la0, prec_sws16_la50, prec_sws16_la100, prec_sws16_la150, prec_sws16_la200],
        [prec_sws32_la0, prec_sws32_la50, prec_sws32_la100, prec_sws32_la150, prec_sws32_la200],
        [prec_sws64_la0, prec_sws64_la50, prec_sws64_la100, prec_sws64_la150, prec_sws64_la200],
        [prec_sws128_la0, prec_sws128_la50, prec_sws128_la100, prec_sws128_la150, prec_sws128_la200],
        [prec_sws256_la0, prec_sws256_la50, prec_sws256_la100, prec_sws256_la150, prec_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, precision, 20, alpha=0.6, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Precision (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_precision_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %%
# specificity
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
spec = np.array(
    [
        [spec_sws8_la0, spec_sws8_la50, spec_sws8_la100, spec_sws8_la150, spec_sws8_la200],
        [spec_sws16_la0, spec_sws16_la50, spec_sws16_la100, spec_sws16_la150, spec_sws16_la200],
        [spec_sws32_la0, spec_sws32_la50, spec_sws32_la100, spec_sws32_la150, spec_sws32_la200],
        [spec_sws64_la0, spec_sws64_la50, spec_sws64_la100, spec_sws64_la150, spec_sws64_la200],
        [spec_sws128_la0, spec_sws128_la50, spec_sws128_la100, spec_sws128_la150, spec_sws128_la200],
        [spec_sws256_la0, spec_sws256_la50, spec_sws256_la100, spec_sws256_la150, spec_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, spec, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Specificity (TNR) (CNN)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'cnn_model_specificity_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %% [markdown]
# ## Feature Model

# %% [markdown]
# ### Feature (sws=8)

# %%
# la = 0
tn_sws8_la0, fp_sws8_la0, tp_sws8_la0, fn_sws8_la0 = 102514, 2017, 15704, 5721
err_sws8_la0 = calculate_error_rate(fp_sws8_la0, fn_sws8_la0, tp_sws8_la0, tn_sws8_la0)
acc_sws8_la0 = calculate_accuracy(fp_sws8_la0, fn_sws8_la0, tp_sws8_la0, tn_sws8_la0)
rec_sws8_la0 = calculate_recall(fn_sws8_la0, tp_sws8_la0)
spec_sws8_la0 = calculate_specificity(fp_sws8_la0, tn_sws8_la0)
prec_sws8_la0 = calculate_precision(tp_sws8_la0, fp_sws8_la0)

# la = 50
tn_sws8_la50, fp_sws8_la50, tp_sws8_la50, fn_sws8_la50 = 101210, 521, 14178, 7247
err_sws8_la50 = calculate_error_rate(fp_sws8_la50, fn_sws8_la50, tp_sws8_la50, tn_sws8_la50)
acc_sws8_la50 = calculate_accuracy(fp_sws8_la50, fn_sws8_la50, tp_sws8_la50, tn_sws8_la50)
rec_sws8_la50 = calculate_recall(fn_sws8_la50, tp_sws8_la50)
spec_sws8_la50 = calculate_specificity(fp_sws8_la50, tn_sws8_la50)
prec_sws8_la50 = calculate_precision(tp_sws8_la50, fp_sws8_la50)

# la = 100
tn_sws8_la100, fp_sws8_la100, tp_sws8_la100, fn_sws8_la100 = 100821, 13, 10345, 9177
err_sws8_la100 = calculate_error_rate(fp_sws8_la100, fn_sws8_la100, tp_sws8_la100, tn_sws8_la100)
acc_sws8_la100 = calculate_accuracy(fp_sws8_la100, fn_sws8_la100, tp_sws8_la100, tn_sws8_la100)
rec_sws8_la100 = calculate_recall(fn_sws8_la100, tp_sws8_la100)
spec_sws8_la100 = calculate_specificity(fp_sws8_la100, tn_sws8_la100)
prec_sws8_la100 = calculate_precision(tp_sws8_la100, fp_sws8_la100)

# la = 150
tn_sws8_la150, fp_sws8_la150, tp_sws8_la150, fn_sws8_la150 = 100834, 0, 0, 16722
err_sws8_la150 = calculate_error_rate(fp_sws8_la150, fn_sws8_la150, tp_sws8_la150, tn_sws8_la150)
acc_sws8_la150 = calculate_accuracy(fp_sws8_la150, fn_sws8_la150, tp_sws8_la150, tn_sws8_la150)
rec_sws8_la150 = calculate_recall(fn_sws8_la150, tp_sws8_la150)
spec_sws8_la150 = calculate_specificity(fp_sws8_la150, tn_sws8_la150)
# prec_sws8_la150 = calculate_precision(tp_sws8_la150, fp_sws8_la150)

# la = 200
tn_sws8_la200, fp_sws8_la200, tp_sws8_la200, fn_sws8_la200 = 100834, 0, 0, 13922
err_sws8_la200 = calculate_error_rate(fp_sws8_la200, fn_sws8_la200, tp_sws8_la200, tn_sws8_la200)
acc_sws8_la200 = calculate_accuracy(fp_sws8_la200, fn_sws8_la200, tp_sws8_la200, tn_sws8_la200)
rec_sws8_la200 = calculate_recall(fn_sws8_la200, tp_sws8_la200)
spec_sws8_la200 = calculate_specificity(fp_sws8_la200, tn_sws8_la200)
# prec_sws8_la200 = calculate_precision(tp_sws8_la200, fp_sws8_la200)

# %% [markdown]
# ### Feature (sws=16)

# %%
# la = 0
tn_sws16_la0, fp_sws16_la0, tp_sws16_la0, fn_sws16_la0 = 102125, 1958, 16561, 4864
err_sws16_la0 = calculate_error_rate(fp_sws16_la0, fn_sws16_la0, tp_sws16_la0, tn_sws16_la0)
acc_sws16_la0 = calculate_accuracy(fp_sws16_la0, fn_sws16_la0, tp_sws16_la0, tn_sws16_la0)
rec_sws16_la0 = calculate_recall(fn_sws16_la0, tp_sws16_la0)
spec_sws16_la0 = calculate_specificity(fp_sws16_la0, tn_sws16_la0)
prec_sws16_la0 = calculate_precision(tp_sws16_la0, fp_sws16_la0)

# la = 50
tn_sws16_la50, fp_sws16_la50, tp_sws16_la50, fn_sws16_la50 = 100639, 644, 16933, 4492
err_sws16_la50 = calculate_error_rate(fp_sws16_la50, fn_sws16_la50, tp_sws16_la50, tn_sws16_la50)
acc_sws16_la50 = calculate_accuracy(fp_sws16_la50, fn_sws16_la50, tp_sws16_la50, tn_sws16_la50)
rec_sws16_la50 = calculate_recall(fn_sws16_la50, tp_sws16_la50)
spec_sws16_la50 = calculate_specificity(fp_sws16_la50, tn_sws16_la50)
prec_sws16_la50 = calculate_precision(tp_sws16_la50, fp_sws16_la50)

# la = 100
tn_sws16_la100, fp_sws16_la100, tp_sws16_la100, fn_sws16_la100 = 100674, 160, 13939, 5135
err_sws16_la100 = calculate_error_rate(fp_sws16_la100, fn_sws16_la100, tp_sws16_la100, tn_sws16_la100)
acc_sws16_la100 = calculate_accuracy(fp_sws16_la100, fn_sws16_la100, tp_sws16_la100, tn_sws16_la100)
rec_sws16_la100 = calculate_recall(fn_sws16_la100, tp_sws16_la100)
spec_sws16_la100 = calculate_specificity(fp_sws16_la100, tn_sws16_la100)
prec_sws16_la100 = calculate_precision(tp_sws16_la100, fp_sws16_la100)

# la = 150
tn_sws16_la150, fp_sws16_la150, tp_sws16_la150, fn_sws16_la150 = 100692, 142, 11464, 4810
err_sws16_la150 = calculate_error_rate(fp_sws16_la150, fn_sws16_la150, tp_sws16_la150, tn_sws16_la150)
acc_sws16_la150 = calculate_accuracy(fp_sws16_la150, fn_sws16_la150, tp_sws16_la150, tn_sws16_la150)
rec_sws16_la150 = calculate_recall(fn_sws16_la150, tp_sws16_la150)
spec_sws16_la150 = calculate_specificity(fp_sws16_la150, tn_sws16_la150)
prec_sws16_la150 = calculate_precision(tp_sws16_la150, fp_sws16_la150)

# la = 200
tn_sws16_la200, fp_sws16_la200, tp_sws16_la200, fn_sws16_la200 = 100827, 0, 0, 13481
err_sws16_la200 = calculate_error_rate(fp_sws16_la200, fn_sws16_la200, tp_sws16_la200, tn_sws16_la200)
acc_sws16_la200 = calculate_accuracy(fp_sws16_la200, fn_sws16_la200, tp_sws16_la200, tn_sws16_la200)
rec_sws16_la200 = calculate_recall(fn_sws16_la200, tp_sws16_la200)
spec_sws16_la200 = calculate_specificity(fp_sws16_la200, tn_sws16_la200)
# prec_sws16_la200 = calculate_precision(tp_sws16_la200, fp_sws16_la200)

# %% [markdown]
# ### Feature (sws=32)

# %%
# la = 0
tn_sws32_la0, fp_sws32_la0, tp_sws32_la0, fn_sws32_la0 = 101625, 1562, 17171, 4254
err_sws32_la0 = calculate_error_rate(fp_sws32_la0, fn_sws32_la0, tp_sws32_la0, tn_sws32_la0)
acc_sws32_la0 = calculate_accuracy(fp_sws32_la0, fn_sws32_la0, tp_sws32_la0, tn_sws32_la0)
rec_sws32_la0 = calculate_recall(fn_sws32_la0, tp_sws32_la0)
spec_sws32_la0 = calculate_specificity(fp_sws32_la0, tn_sws32_la0)
prec_sws32_la0 = calculate_precision(tp_sws32_la0, fp_sws32_la0)

# la = 50
tn_sws32_la50, fp_sws32_la50, tp_sws32_la50, fn_sws32_la50 = 100528, 306, 16917, 4061
err_sws32_la50 = calculate_error_rate(fp_sws32_la50, fn_sws32_la50, tp_sws32_la50, tn_sws32_la50)
acc_sws32_la50 = calculate_accuracy(fp_sws32_la50, fn_sws32_la50, tp_sws32_la50, tn_sws32_la50)
rec_sws32_la50 = calculate_recall(fn_sws32_la50, tp_sws32_la50)
spec_sws32_la50 = calculate_specificity(fp_sws32_la50, tn_sws32_la50)
prec_sws32_la50 = calculate_precision(tp_sws32_la50, fp_sws32_la50)

# la = 100
tn_sws32_la100, fp_sws32_la100, tp_sws32_la100, fn_sws32_la100 = 100594, 240, 14638, 3540
err_sws32_la100 = calculate_error_rate(fp_sws32_la100, fn_sws32_la100, tp_sws32_la100, tn_sws32_la100)
acc_sws32_la100 = calculate_accuracy(fp_sws32_la100, fn_sws32_la100, tp_sws32_la100, tn_sws32_la100)
rec_sws32_la100 = calculate_recall(fn_sws32_la100, tp_sws32_la100)
spec_sws32_la100 = calculate_specificity(fp_sws32_la100, tn_sws32_la100)
prec_sws32_la100 = calculate_precision(tp_sws32_la100, fp_sws32_la100)

# la = 150
tn_sws32_la150, fp_sws32_la150, tp_sws32_la150, fn_sws32_la150 = 100636, 198, 11739, 3639
err_sws32_la150 = calculate_error_rate(fp_sws32_la150, fn_sws32_la150, tp_sws32_la150, tn_sws32_la150)
acc_sws32_la150 = calculate_accuracy(fp_sws32_la150, fn_sws32_la150, tp_sws32_la150, tn_sws32_la150)
rec_sws32_la150 = calculate_recall(fn_sws32_la150, tp_sws32_la150)
spec_sws32_la150 = calculate_specificity(fp_sws32_la150, tn_sws32_la150)
prec_sws32_la150 = calculate_precision(tp_sws32_la150, fp_sws32_la150)

# la = 200
tn_sws32_la200, fp_sws32_la200, tp_sws32_la200, fn_sws32_la200 = 100563, 248, 9410, 3191
err_sws32_la200 = calculate_error_rate(fp_sws32_la200, fn_sws32_la200, tp_sws32_la200, tn_sws32_la200)
acc_sws32_la200 = calculate_accuracy(fp_sws32_la200, fn_sws32_la200, tp_sws32_la200, tn_sws32_la200)
rec_sws32_la200 = calculate_recall(fn_sws32_la200, tp_sws32_la200)
spec_sws32_la200 = calculate_specificity(fp_sws32_la200, tn_sws32_la200)
prec_sws32_la200 = calculate_precision(tp_sws32_la200, fp_sws32_la200)

# %% [markdown]
# ### Feature (sws=64)

# %%
# la = 0
tn_sws64_la0, fp_sws64_la0, tp_sws64_la0, fn_sws64_la0 = 100477, 918, 19028, 2397
err_sws64_la0 = calculate_error_rate(fp_sws64_la0, fn_sws64_la0, tp_sws64_la0, tn_sws64_la0)
acc_sws64_la0 = calculate_accuracy(fp_sws64_la0, fn_sws64_la0, tp_sws64_la0, tn_sws64_la0)
rec_sws64_la0 = calculate_recall(fn_sws64_la0, tp_sws64_la0)
spec_sws64_la0 = calculate_specificity(fp_sws64_la0, tn_sws64_la0)
prec_sws64_la0 = calculate_precision(tp_sws64_la0, fp_sws64_la0)

# la = 50
tn_sws64_la50, fp_sws64_la50, tp_sws64_la50, fn_sws64_la50 = 100007, 827, 16914, 2272
err_sws64_la50 = calculate_error_rate(fp_sws64_la50, fn_sws64_la50, tp_sws64_la50, tn_sws64_la50)
acc_sws64_la50 = calculate_accuracy(fp_sws64_la50, fn_sws64_la50, tp_sws64_la50, tn_sws64_la50)
rec_sws64_la50 = calculate_recall(fn_sws64_la50, tp_sws64_la50)
spec_sws64_la50 = calculate_specificity(fp_sws64_la50, tn_sws64_la50)
prec_sws64_la50 = calculate_precision(tp_sws64_la50, fp_sws64_la50)

# la = 100
tn_sws64_la100, fp_sws64_la100, tp_sws64_la100, fn_sws64_la100 = 100360, 474, 14462, 1924
err_sws64_la100 = calculate_error_rate(fp_sws64_la100, fn_sws64_la100, tp_sws64_la100, tn_sws64_la100)
acc_sws64_la100 = calculate_accuracy(fp_sws64_la100, fn_sws64_la100, tp_sws64_la100, tn_sws64_la100)
rec_sws64_la100 = calculate_recall(fn_sws64_la100, tp_sws64_la100)
spec_sws64_la100 = calculate_specificity(fp_sws64_la100, tn_sws64_la100)
prec_sws64_la100 = calculate_precision(tp_sws64_la100, fp_sws64_la100)

# la = 150
tn_sws64_la150, fp_sws64_la150, tp_sws64_la150, fn_sws64_la150 = 100419, 410, 11673, 1918
err_sws64_la150 = calculate_error_rate(fp_sws64_la150, fn_sws64_la150, tp_sws64_la150, tn_sws64_la150)
acc_sws64_la150 = calculate_accuracy(fp_sws64_la150, fn_sws64_la150, tp_sws64_la150, tn_sws64_la150)
rec_sws64_la150 = calculate_recall(fn_sws64_la150, tp_sws64_la150)
spec_sws64_la150 = calculate_specificity(fp_sws64_la150, tn_sws64_la150)
prec_sws64_la150 = calculate_precision(tp_sws64_la150, fp_sws64_la150)

# la = 200
tn_sws64_la200, fp_sws64_la200, tp_sws64_la200, fn_sws64_la200 = 100531, 227, 8317, 2545
err_sws64_la200 = calculate_error_rate(fp_sws64_la200, fn_sws64_la200, tp_sws64_la200, tn_sws64_la200)
acc_sws64_la200 = calculate_accuracy(fp_sws64_la200, fn_sws64_la200, tp_sws64_la200, tn_sws64_la200)
rec_sws64_la200 = calculate_recall(fn_sws64_la200, tp_sws64_la200)
spec_sws64_la200 = calculate_specificity(fp_sws64_la200, tn_sws64_la200)
prec_sws64_la200 = calculate_precision(tp_sws64_la200, fp_sws64_la200)

# %% [markdown]
# ### Feature (sws=128)

# %%
# la = 0
tn_sws128_la0, fp_sws128_la0, tp_sws128_la0, fn_sws128_la0 = 97998, 2836, 16646, 1756
err_sws128_la0 = calculate_error_rate(fp_sws128_la0, fn_sws128_la0, tp_sws128_la0, tn_sws128_la0)
acc_sws128_la0 = calculate_accuracy(fp_sws128_la0, fn_sws128_la0, tp_sws128_la0, tn_sws128_la0)
rec_sws128_la0 = calculate_recall(fn_sws128_la0, tp_sws128_la0)
spec_sws128_la0 = calculate_specificity(fp_sws128_la0, tn_sws128_la0)
prec_sws128_la0 = calculate_precision(tp_sws128_la0, fp_sws128_la0)

# la = 50
tn_sws128_la50, fp_sws128_la50, tp_sws128_la50, fn_sws128_la50 = 98164, 2670, 14331, 1271
err_sws128_la50 = calculate_error_rate(fp_sws128_la50, fn_sws128_la50, tp_sws128_la50, tn_sws128_la50)
acc_sws128_la50 = calculate_accuracy(fp_sws128_la50, fn_sws128_la50, tp_sws128_la50, tn_sws128_la50)
rec_sws128_la50 = calculate_recall(fn_sws128_la50, tp_sws128_la50)
spec_sws128_la50 = calculate_specificity(fp_sws128_la50, tn_sws128_la50)
prec_sws128_la50 = calculate_precision(tp_sws128_la50, fp_sws128_la50)

# la = 100
tn_sws128_la100, fp_sws128_la100, tp_sws128_la100, fn_sws128_la100 = 98331, 2484, 12523, 298
err_sws128_la100 = calculate_error_rate(fp_sws128_la100, fn_sws128_la100, tp_sws128_la100, tn_sws128_la100)
acc_sws128_la100 = calculate_accuracy(fp_sws128_la100, fn_sws128_la100, tp_sws128_la100, tn_sws128_la100)
rec_sws128_la100 = calculate_recall(fn_sws128_la100, tp_sws128_la100)
spec_sws128_la100 = calculate_specificity(fp_sws128_la100, tn_sws128_la100)
prec_sws128_la100 = calculate_precision(tp_sws128_la100, fp_sws128_la100)

# la = 150
tn_sws128_la150, fp_sws128_la150, tp_sws128_la150, fn_sws128_la150 = 99065, 1633, 9745, 393
err_sws128_la150 = calculate_error_rate(fp_sws128_la150, fn_sws128_la150, tp_sws128_la150, tn_sws128_la150)
acc_sws128_la150 = calculate_accuracy(fp_sws128_la150, fn_sws128_la150, tp_sws128_la150, tn_sws128_la150)
rec_sws128_la150 = calculate_recall(fn_sws128_la150, tp_sws128_la150)
spec_sws128_la150 = calculate_specificity(fp_sws128_la150, tn_sws128_la150)
prec_sws128_la150 = calculate_precision(tp_sws128_la150, fp_sws128_la150)

# la = 200
tn_sws128_la200, fp_sws128_la200, tp_sws128_la200, fn_sws128_la200 = 100256, 0, 1598, 6182
err_sws128_la200 = calculate_error_rate(fp_sws128_la200, fn_sws128_la200, tp_sws128_la200, tn_sws128_la200)
acc_sws128_la200 = calculate_accuracy(fp_sws128_la200, fn_sws128_la200, tp_sws128_la200, tn_sws128_la200)
rec_sws128_la200 = calculate_recall(fn_sws128_la200, tp_sws128_la200)
spec_sws128_la200 = calculate_specificity(fp_sws128_la200, tn_sws128_la200)
prec_sws128_la200 = calculate_precision(tp_sws128_la200, fp_sws128_la200)

# %% [markdown]
# ### Feature (sws=256)

# %%
# la = 0
tn_sws256_la0, fp_sws256_la0, tp_sws256_la0, fn_sws256_la0 = 90539, 10243, 9247, 2039
err_sws256_la0 = calculate_error_rate(fp_sws256_la0, fn_sws256_la0, tp_sws256_la0, tn_sws256_la0)
acc_sws256_la0 = calculate_accuracy(fp_sws256_la0, fn_sws256_la0, tp_sws256_la0, tn_sws256_la0)
rec_sws256_la0 = calculate_recall(fn_sws256_la0, tp_sws256_la0)
spec_sws256_la0 = calculate_specificity(fp_sws256_la0, tn_sws256_la0)
prec_sws256_la0 = calculate_precision(tp_sws256_la0, fp_sws256_la0)

# la = 50
tn_sws256_la50, fp_sws256_la50, tp_sws256_la50, fn_sws256_la50 = 90712, 9789, 8432, 335
err_sws256_la50 = calculate_error_rate(fp_sws256_la50, fn_sws256_la50, tp_sws256_la50, tn_sws256_la50)
acc_sws256_la50 = calculate_accuracy(fp_sws256_la50, fn_sws256_la50, tp_sws256_la50, tn_sws256_la50)
rec_sws256_la50 = calculate_recall(fn_sws256_la50, tp_sws256_la50)
spec_sws256_la50 = calculate_specificity(fp_sws256_la50, tn_sws256_la50)
prec_sws256_la50 = calculate_precision(tp_sws256_la50, fp_sws256_la50)

# la = 100
tn_sws256_la100, fp_sws256_la100, tp_sws256_la100, fn_sws256_la100 = 90612, 9250, 6394, 212
err_sws256_la100 = calculate_error_rate(fp_sws256_la100, fn_sws256_la100, tp_sws256_la100, tn_sws256_la100)
acc_sws256_la100 = calculate_accuracy(fp_sws256_la100, fn_sws256_la100, tp_sws256_la100, tn_sws256_la100)
rec_sws256_la100 = calculate_recall(fn_sws256_la100, tp_sws256_la100)
spec_sws256_la100 = calculate_specificity(fp_sws256_la100, tn_sws256_la100)
prec_sws256_la100 = calculate_precision(tp_sws256_la100, fp_sws256_la100)

# la = 150
tn_sws256_la150, fp_sws256_la150, tp_sws256_la150, fn_sws256_la150 = 92077, 6949, 4642, 0
err_sws256_la150 = calculate_error_rate(fp_sws256_la150, fn_sws256_la150, tp_sws256_la150, tn_sws256_la150)
acc_sws256_la150 = calculate_accuracy(fp_sws256_la150, fn_sws256_la150, tp_sws256_la150, tn_sws256_la150)
rec_sws256_la150 = calculate_recall(fn_sws256_la150, tp_sws256_la150)
spec_sws256_la150 = calculate_specificity(fp_sws256_la150, tn_sws256_la150)
prec_sws256_la150 = calculate_precision(tp_sws256_la150, fp_sws256_la150)

# la = 200
tn_sws256_la200, fp_sws256_la200, tp_sws256_la200, fn_sws256_la200 = 92554, 5161, 3094, 59
err_sws256_la200 = calculate_error_rate(fp_sws256_la200, fn_sws256_la200, tp_sws256_la200, tn_sws256_la200)
acc_sws256_la200 = calculate_accuracy(fp_sws256_la200, fn_sws256_la200, tp_sws256_la200, tn_sws256_la200)
rec_sws256_la200 = calculate_recall(fn_sws256_la200, tp_sws256_la200)
spec_sws256_la200 = calculate_specificity(fp_sws256_la200, tn_sws256_la200)
prec_sws256_la200 = calculate_precision(tp_sws256_la200, fp_sws256_la200)

# %% [markdown]
# ### Plots (no extended sws)

# %%
# error rate
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
error_rates = np.array(
    [
        [err_sws8_la0, err_sws8_la50, err_sws8_la100, err_sws8_la150, err_sws8_la200],
        [err_sws16_la0, err_sws16_la50, err_sws16_la100, err_sws16_la150, err_sws16_la200],
        [err_sws32_la0, err_sws32_la50, err_sws32_la100, err_sws32_la150, err_sws32_la200],
        [err_sws64_la0, err_sws64_la50, err_sws64_la100, err_sws64_la150, err_sws64_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, error_rates, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Error rates (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_error_rate_wavelet_data.png'), dpi=120)
plt.show()

# %%
# accuracy
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
accuracy = np.array(
    [
        [acc_sws8_la0, acc_sws8_la50, acc_sws8_la100, acc_sws8_la150, acc_sws8_la200],
        [acc_sws16_la0, acc_sws16_la50, acc_sws16_la100, acc_sws16_la150, acc_sws16_la200],
        [acc_sws32_la0, acc_sws32_la50, acc_sws32_la100, acc_sws32_la150, acc_sws32_la200],
        [acc_sws64_la0, acc_sws64_la50, acc_sws64_la100, acc_sws64_la150, acc_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, accuracy, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Accuracy (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_accuracy_wavelet_data.png'), dpi=120)
plt.show()

# %%
# recall
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
recall = np.array(
    [
        [rec_sws8_la0, rec_sws8_la50, rec_sws8_la100, rec_sws8_la150, rec_sws8_la200],
        [rec_sws16_la0, rec_sws16_la50, rec_sws16_la100, rec_sws16_la150, rec_sws16_la200],
        [rec_sws32_la0, rec_sws32_la50, rec_sws32_la100, rec_sws32_la150, rec_sws32_la200],
        [rec_sws64_la0, rec_sws64_la50, rec_sws64_la100, rec_sws64_la150, rec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, recall, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Recall (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_recall_wavelet_data.png'), dpi=120)
plt.show()

# %%
# precision
# la = np.array([0, 50, 100, 150, 200])
# sws = np.array([8, 16, 32, 64])
# X, Y = np.meshgrid(la, sws)
# precision = np.array(
#     [
#         [prec_sws8_la0, prec_sws8_la50, prec_sws8_la100, prec_sws8_la150, prec_sws8_la200],
#         [prec_sws16_la0, prec_sws16_la50, prec_sws16_la100, prec_sws16_la150, prec_sws16_la200],
#         [prec_sws32_la0, prec_sws32_la50, prec_sws32_la100, prec_sws32_la150, prec_sws32_la200],
#         [prec_sws64_la0, prec_sws64_la50, prec_sws64_la100, prec_sws64_la150, prec_sws64_la200]
#     ]
# )
# plt.figure(figsize=(6, 4), dpi=120)
# plt.contourf(X, Y, precision, 20, alpha=0.6, cmap='cubehelix')
# plt.xlabel('Label look ahead')
# plt.ylabel('Signal window size')
# plt.title('Precision (Feature)')
# plt.colorbar()
# plt.tight_layout()
# plt.savefig(os.path.join(base_path, 'feature_model_precision_wavelet_data.png'), dpi=120)
# plt.show()

# %%
# specificity
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64])
X, Y = np.meshgrid(la, sws)
spec = np.array(
    [
        [spec_sws8_la0, spec_sws8_la50, spec_sws8_la100, spec_sws8_la150, spec_sws8_la200],
        [spec_sws16_la0, spec_sws16_la50, spec_sws16_la100, spec_sws16_la150, spec_sws16_la200],
        [spec_sws32_la0, spec_sws32_la50, spec_sws32_la100, spec_sws32_la150, spec_sws32_la200],
        [spec_sws64_la0, spec_sws64_la50, spec_sws64_la100, spec_sws64_la150, spec_sws64_la200]
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, spec, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Specificity (TNR) (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_specificity_wavelet_data.png'), dpi=120)
plt.show()

# %% [markdown]
# ### Plots (extended sws)

# %%
# error rate
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
error_rates = np.array(
    [
        [err_sws8_la0, err_sws8_la50, err_sws8_la100, err_sws8_la150, err_sws8_la200],
        [err_sws16_la0, err_sws16_la50, err_sws16_la100, err_sws16_la150, err_sws16_la200],
        [err_sws32_la0, err_sws32_la50, err_sws32_la100, err_sws32_la150, err_sws32_la200],
        [err_sws64_la0, err_sws64_la50, err_sws64_la100, err_sws64_la150, err_sws64_la200],
        [err_sws128_la0, err_sws128_la50, err_sws128_la100, err_sws128_la150, err_sws128_la200],
        [err_sws256_la0, err_sws256_la50, err_sws256_la100, err_sws256_la150, err_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, error_rates, 20, alpha=0.5, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Error rates (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_error_rate_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %%
# accuracy
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
accuracy = np.array(
    [
        [acc_sws8_la0, acc_sws8_la50, acc_sws8_la100, acc_sws8_la150, acc_sws8_la200],
        [acc_sws16_la0, acc_sws16_la50, acc_sws16_la100, acc_sws16_la150, acc_sws16_la200],
        [acc_sws32_la0, acc_sws32_la50, acc_sws32_la100, acc_sws32_la150, acc_sws32_la200],
        [acc_sws64_la0, acc_sws64_la50, acc_sws64_la100, acc_sws64_la150, acc_sws64_la200],
        [acc_sws128_la0, acc_sws128_la50, acc_sws128_la100, acc_sws128_la150, acc_sws128_la200],
        [acc_sws256_la0, acc_sws256_la50, acc_sws256_la100, acc_sws256_la150, acc_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, accuracy, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Accuracy (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_accuracy_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %%
# recall
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
recall = np.array(
    [
        [rec_sws8_la0, rec_sws8_la50, rec_sws8_la100, rec_sws8_la150, rec_sws8_la200],
        [rec_sws16_la0, rec_sws16_la50, rec_sws16_la100, rec_sws16_la150, rec_sws16_la200],
        [rec_sws32_la0, rec_sws32_la50, rec_sws32_la100, rec_sws32_la150, rec_sws32_la200],
        [rec_sws64_la0, rec_sws64_la50, rec_sws64_la100, rec_sws64_la150, rec_sws64_la200],
        [rec_sws128_la0, rec_sws128_la50, rec_sws128_la100, rec_sws128_la150, rec_sws128_la200],
        [rec_sws256_la0, rec_sws256_la50, rec_sws256_la100, rec_sws256_la150, rec_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, recall, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Recall (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_recall_wavelet_data_extended_sws.png'), dpi=120)
plt.show()

# %%
# precision
# la = np.array([0, 50, 100, 150, 200])
# sws = np.array([8, 16, 32, 64, 128, 256])
# X, Y = np.meshgrid(la, sws)
# precision = np.array(
#     [
#         [prec_sws8_la0, prec_sws8_la50, prec_sws8_la100, prec_sws8_la150, prec_sws8_la200],
#         [prec_sws16_la0, prec_sws16_la50, prec_sws16_la100, prec_sws16_la150, prec_sws16_la200],
#         [prec_sws32_la0, prec_sws32_la50, prec_sws32_la100, prec_sws32_la150, prec_sws32_la200],
#         [prec_sws64_la0, prec_sws64_la50, prec_sws64_la100, prec_sws64_la150, prec_sws64_la200],
#         [prec_sws128_la0, prec_sws128_la50, prec_sws128_la100, prec_sws128_la150, prec_sws128_la200],
#         [prec_sws256_la0, prec_sws256_la50, prec_sws256_la100, prec_sws256_la150, prec_sws256_la200],
#     ]
# )
# plt.figure(figsize=(6, 4), dpi=120)
# plt.contourf(X, Y, precision, 20, alpha=0.6, cmap='cubehelix')
# plt.xlabel('Label look ahead')
# plt.ylabel('Signal window size')
# plt.title('Precision (Feature)')
# plt.colorbar()
# plt.tight_layout()
# plt.savefig(os.path.join(base_path, 'feature_model_precision_wavelet_data_extended_sws.png'), dpi=120)
# plt.show()

# %%
# specificity
la = np.array([0, 50, 100, 150, 200])
sws = np.array([8, 16, 32, 64, 128, 256])
X, Y = np.meshgrid(la, sws)
spec = np.array(
    [
        [spec_sws8_la0, spec_sws8_la50, spec_sws8_la100, spec_sws8_la150, spec_sws8_la200],
        [spec_sws16_la0, spec_sws16_la50, spec_sws16_la100, spec_sws16_la150, spec_sws16_la200],
        [spec_sws32_la0, spec_sws32_la50, spec_sws32_la100, spec_sws32_la150, spec_sws32_la200],
        [spec_sws64_la0, spec_sws64_la50, spec_sws64_la100, spec_sws64_la150, spec_sws64_la200],
        [spec_sws128_la0, spec_sws128_la50, spec_sws128_la100, spec_sws128_la150, spec_sws128_la200],
        [spec_sws256_la0, spec_sws256_la50, spec_sws256_la100, spec_sws256_la150, spec_sws256_la200],
    ]
)
plt.figure(figsize=(6, 4), dpi=120)
plt.contourf(X, Y, spec, 20, alpha=0.65, cmap='cubehelix')
plt.xlabel('Label look ahead')
plt.ylabel('Signal window size')
plt.title('Specificity (TNR) (Feature)')
plt.colorbar()
plt.tight_layout()
plt.savefig(os.path.join(base_path, 'feature_model_specificity_wavelet_data_extended_sws.png'), dpi=120)
plt.show()
